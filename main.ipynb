# %%
import pandas as pd

# %%
df_total = pd.read_excel(io='stadat-iga0008-11.1.2.1-en.xlsx', sheet_name='total')
df_total
# Out:
#    Name of the territorial unit Territory name   Quarter    2009    2010  \
# 0                      Budapest        Central       NaN  104253  110755
# 1                          Pest        Central       NaN   36656   37200
# 2                         Fejér   Transdanubia   Central   15612   19643
# 3             Komárom-Esztergom   Transdanubia   Central   12665   14209
# 4                      Veszprém   Transdanubia   Central   10285   13052
# 5             Győr-Moson-Sopron   Transdanubia   Western   13875   16441
# 6                           Vas   Transdanubia   Western    7045    8467
# 7                          Zala   Transdanubia   Western    8946   10148
# 8                       Baranya   Transdanubia  Southern   13981   15415
# 9                        Somogy   Transdanubia  Southern   13091   21672
# 10                        Tolna   Transdanubia  Southern    7616    9938
# 11         Borsod-Abaúj-Zemplén       Northern       NaN   24428   26778
# ...
